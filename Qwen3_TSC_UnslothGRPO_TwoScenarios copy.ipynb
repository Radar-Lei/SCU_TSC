# %% [markdown]
# # TSC 标准 Unsloth GRPO 训练（两大场景）
#
# 使用标准 Unsloth GRPOTrainer + 离线 Dataset + Reward Function 回溯 SUMO 评估

# %% [markdown]
# ## 1. 环境配置

# %%
import os
import sys

os.environ["UNSLOTH_USE_MODELSCOPE"] = "1"
os.environ["UNSLOTH_VLLM_STANDBY"] = "1"
os.environ["MODELSCOPE_CACHE"] = "model"
os.environ["HF_HOME"] = "model"
print("环境变量已设置")
# Out:
# 环境变量已设置

# %% [markdown]
# ## 1.5 生成/检查 Dataset（可选）
#
# 如果 dataset 不存在，此 cell 会自动生成；如果已存在，则跳过。

# %%
from generate_grpo_dataset import main as generate_main, CONFIG

DATASET_PATH = "grpo_dataset_two_scenarios"

if not os.path.isdir(DATASET_PATH):
    print(f"⚠️ Dataset 不存在: {DATASET_PATH}")
    print("开始生成 dataset...")

    # 快速验证模式：取消下面注释以使用小规模dataset
    # QUICK_VERIFY = True
    QUICK_VERIFY = False  # 正式训练设为 False

    CONFIG.update({
        "output_dir": DATASET_PATH,
        "state_dir": "grpo_states_two_scenarios",
        "dataset_mode": "two_scenarios",
        "steps_per_tl_signal_step": 20,   # 每TL生成10个signal_step样本
        "steps_per_tl_extend_decision": 20,  # 每TL生成100个extend_decision样本
        "decision_lead_sec": 10,
        "phase_duration_scale_range": (0.7, 1.3),
        "extend_min_green_range": (10, 45),
        "extend_max_green_range": (80, 120),
        "extend_wait_time_range": (2, 5),
        "max_extend_sec": 8,  # extend_decision 中 extend_sec 的最大值
        "max_tl_per_scenario": 20,  
        "num_workers": 4 if QUICK_VERIFY else 16,
    })

    print("当前配置:")
    print(f"  - 模式: {'快速验证' if QUICK_VERIFY else '正式训练'}")
    print(f"  - warmup_steps: {CONFIG['warmup_steps']}")
    print(f"  - steps_per_tl_signal_step: {CONFIG['steps_per_tl_signal_step']}")
    print(f"  - steps_per_tl_extend_decision: {CONFIG['steps_per_tl_extend_decision']}")
    print(f"  - max_tl_per_scenario: {CONFIG['max_tl_per_scenario']}")
    print(f"  - num_workers: {CONFIG['num_workers']}")

    generate_main()
else:
    print(f"✓ Dataset 已存在: {DATASET_PATH}")
# Out:
# ⚠️ Dataset 不存在: grpo_dataset_two_scenarios
# 开始生成 dataset...
# 当前配置:
#   - 模式: 正式训练
#   - warmup_steps: 80
#   - steps_per_tl_signal_step: 20
#   - steps_per_tl_extend_decision: 20
#   - max_tl_per_scenario: 20
#   - num_workers: 16
# 发现场景数: 51
# 总训练组合数: 820
#   优先场景: 0
#   其他场景: 820
#   并行 workers: 16
#
# 开始并行生成（16 workers）...
# 端口范围: 30000-40000
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_22/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34852 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_43/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30114 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_44/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34566 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_46/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31887 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_19/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32409 (Attempt 1/3)
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_42/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37098 (Attempt 1/3)
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_11/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36950 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_44/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32676 (Attempt 1/3)
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_25/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35617 (Attempt 1/3)
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39806 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30177 (Attempt 1/3)
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_3/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32009 (Attempt 1/3)
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32495 (Attempt 1/3)
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_23/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38717 (Attempt 1/3)
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_3/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33307 (Attempt 1/3)
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_30/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32860 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 34852
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 30114
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 34566
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 31887
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 32409
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 37098
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 35617
# Successfully connected to SUMO
# Starting warmup phase...
# Successfully connected to SUMO on port 32676
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 0/300
# Successfully connected to SUMO on port 36950
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 39806
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 32009
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 30177
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 32495
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 38717
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 33307
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 32860
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Step #627.00 (1ms ~= 1000.00*RT, ~165000.00UPS, TraCI: 2ms, vehicles TOT 249 ACT 165 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [1/820] ✓ arterial4x4_44/nt7: 3 个样本，累计 3 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_24/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39671 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #640.00 (1ms ~= 1000.00*RT, ~169000.00UPS, TraCI: 2ms, vehicles TOT 252 ACT 169 BUF 1
# [2/820] ✓ arterial4x4_47/nt8: 3 个样本，累计 6 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_23/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34646 (Attempt 1/3)
# Step #650.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 2ms, vehicles TOT 256 ACT 177 BUF 1
#  Retrying in 1 seconds
# [3/820] ✓ arterial4x4_42/nt15: 5 个样本，累计 11 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_21/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32782 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #671.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 2ms, vehicles TOT 266 ACT 174 BUF 1
# [4/820] ✓ arterial4x4_30/nt5: 0 个样本，累计 11 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_20/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38983 (Attempt 1/3)
# Step #682.00 (1ms ~= 1000.00*RT, ~180000.00UPS, TraCI: 2ms, vehicles TOT 268 ACT 180 BUF 1
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [5/820] ✓ arterial4x4_19/nt15: 4 个样本，累计 15 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_4/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39164 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #690.00 (2ms ~= 500.00*RT, ~88500.00UPS, TraCI: 2ms, vehicles TOT 270 ACT 177 BUF 138
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [6/820] ✓ arterial4x4_44/nt4: 4 个样本，累计 19 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_43/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36411 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #672.00 (1ms ~= 1000.00*RT, ~176000.00UPS, TraCI: 3ms, vehicles TOT 268 ACT 176 BUF 1
# Step #681.00 (1ms ~= 1000.00*RT, ~188000.00UPS, TraCI: 2ms, vehicles TOT 269 ACT 188 BUF 1
# [7/820] ✓ arterial4x4_11/nt1: 3 个样本，累计 22 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_41/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30650 (Attempt 1/3)
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_42/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34597 (Attempt 1/3)
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# [8/820] ✓ arterial4x4_46/nt15: 6 个样本，累计 28 个
# Step #689.00 (1ms ~= 1000.00*RT, ~173000.00UPS, TraCI: 4ms, vehicles TOT 270 ACT 173 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_32/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39533 (Attempt 1/3)
# [9/820] ✓ arterial4x4_3/nt16: 3 个样本，累计 31 个
#  Retrying in 1 seconds
# Step #694.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 2ms, vehicles TOT 271 ACT 174 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [10/820] ✓ arterial4x4_47/nt9: 0 个样本，累计 31 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_4/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34410 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #653.00 (1ms ~= 1000.00*RT, ~173000.00UPS, TraCI: 2ms, vehicles TOT 256 ACT 173 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_31/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36334 (Attempt 1/3)
# [11/820] ✓ arterial4x4_3/nt14: 14 个样本，累计 45 个
#  Retrying in 1 seconds
# Step #657.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 2ms, vehicles TOT 259 ACT 174 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_5/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35405 (Attempt 1/3)
# [12/820] ✓ arterial4x4_23/nt2: 19 个样本，累计 64 个
#  Retrying in 1 seconds
# Step #732.00 (1ms ~= 1000.00*RT, ~182000.00UPS, TraCI: 2ms, vehicles TOT 280 ACT 182 BUF 1
# [13/820] ✓ arterial4x4_22/nt4: 3 个样本，累计 67 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_29/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34061 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #679.00 (1ms ~= 1000.00*RT, ~173000.00UPS, TraCI: 2ms, vehicles TOT 264 ACT 173 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [14/820] ✓ arterial4x4_25/nt3: 20 个样本，累计 87 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_7/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34390 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #697.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 2ms, vehicles TOT 265 ACT 175 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_28/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38423 (Attempt 1/3)
# [15/820] ✓ arterial4x4_43/nt3: 20 个样本，累计 107 个
#  Retrying in 1 seconds
# Step #679.00 (2ms ~= 500.00*RT, ~85500.00UPS, TraCI: 2ms, vehicles TOT 265 ACT 171 BUF 133
# [16/820] ✓ arterial4x4_47/nt3: 20 个样本，累计 127 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_14/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33959 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 39671
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 34646
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 32782
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 38983
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 39164
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 36411
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 30650
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 34597
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 39533
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 34410
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Successfully connected to SUMO on port 36334
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 35405
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Successfully connected to SUMO on port 34061
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Successfully connected to SUMO on port 34390
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 38423
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Successfully connected to SUMO on port 33959
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Step #641.00 (1ms ~= 1000.00*RT, ~170000.00UPS, TraCI: 2ms, vehicles TOT 252 ACT 170 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [17/820] ✓ arterial4x4_21/nt6: 3 个样本，累计 130 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_44/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37859 (Attempt 1/3)
# Step #650.00 (1ms ~= 1000.00*RT, ~172000.00UPS, TraCI: 2ms, vehicles TOT 256 ACT 172 BUF 1
#  Retrying in 1 seconds
# [18/820] ✓ arterial4x4_24/nt8: 1 个样本，累计 131 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_5/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31147 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #640.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 253 ACT 174 BUF 111)
# [19/820] ✓ arterial4x4_4/nt11: 1 个样本，累计 132 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_6/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38395 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #718.00 (2ms ~= 500.00*RT, ~91500.00UPS, TraCI: 3ms, vehicles TOT 275 ACT 183 BUF 159
# [20/820] ✓ arterial4x4_23/nt10: 1 个样本，累计 133 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_15/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37137 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #723.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 177 BUF 1
# Step #682.00 (1ms ~= 1000.00*RT, ~188000.00UPS, TraCI: 1ms, vehicles TOT 270 ACT 188 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [21/820] ✓ arterial4x4_41/nt1: 2 个样本，累计 135 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_7/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31029 (Attempt 1/3)
#  Retrying in 1 seconds
# [22/820] ✓ arterial4x4_32/nt11: 2 个样本，累计 137 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_12/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34992 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #654.00 (2ms ~= 500.00*RT, ~86000.00UPS, TraCI: 2ms, vehicles TOT 256 ACT 172 BUF 120
# [23/820] ✓ arterial4x4_42/nt8: 3 个样本，累计 140 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_18/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39438 (Attempt 1/3)
# Step #713.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 181 BUF 1
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_2/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37139 (Attempt 1/3)
# [24/820] ✓ arterial4x4_20/nt10: 4 个样本，累计 144 个
#  Retrying in 1 seconds
# Step #701.00 (1ms ~= 1000.00*RT, ~184000.00UPS, TraCI: 2ms, vehicles TOT 271 ACT 184 BUF 1
# [25/820] ✓ arterial4x4_4/nt15: 4 个样本，累计 148 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_43/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35923 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #715.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 177 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_23/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37965 (Attempt 1/3)
# [26/820] ✓ arterial4x4_28/nt4: 3 个样本，累计 151 个
#  Retrying in 1 seconds
# Step #663.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 2ms, vehicles TOT 261 ACT 174 BUF 1
# [27/820] ✓ arterial4x4_7/nt1: 2 个样本，累计 153 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/chengdu/chengdu.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37399 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #787.00 (2ms ~= 500.00*RT, ~100000.00UPS, TraCI: 2ms, vehicles TOT 295 ACT 200 BUF 19
# Step #678.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 271 ACT 181 BUF 1
# [28/820] ✓ arterial4x4_43/nt15: 7 个样本，累计 160 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_43/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33257 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #715.00 (1ms ~= 1000.00*RT, ~183000.00UPS, TraCI: 2ms, vehicles TOT 276 ACT 183 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_4/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31552 (Attempt 1/3)
# [29/820] ✓ arterial4x4_29/nt3: 20 个样本，累计 180 个
#  Retrying in 1 seconds
# [30/820] ✓ arterial4x4_31/nt15: 4 个样本，累计 184 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_37/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31138 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #755.00 (1ms ~= 1000.00*RT, ~180000.00UPS, TraCI: 2ms, vehicles TOT 285 ACT 180 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [31/820] ✓ arterial4x4_5/nt4: 5 个样本，累计 189 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_43/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35290 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #708.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 3ms, vehicles TOT 273 ACT 177 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [32/820] ✓ arterial4x4_14/nt2: 20 个样本，累计 209 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_2/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39683 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 37859
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 31147
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 38395
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 37137
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 31029
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 34992
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 39438
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 37139
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 35923
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 37965
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 33257
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 31552
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 31138
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 35290
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 37399
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 39683
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Step #666.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 2ms, vehicles TOT 263 ACT 175 BUF 1
# [33/820] ✓ arterial4x4_5/nt10: 2 个样本，累计 211 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_22/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31886 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Step #641.00 (1ms ~= 1000.00*RT, ~168000.00UPS, TraCI: 2ms, vehicles TOT 252 ACT 168 BUF 1
# [34/820] ✓ arterial4x4_44/nt16: 2 个样本，累计 213 个DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_15/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39332 (Attempt 1/3)
#
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Step #673.00 (1ms ~= 1000.00*RT, ~179000.00UPS, TraCI: 2ms, vehicles TOT 266 ACT 179 BUF 1
# [35/820] ✓ arterial4x4_2/nt6: 1 个样本，累计 214 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_40/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33191 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #701.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 268 ACT 182 BUF 150)
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_4/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34531 (Attempt 1/3)
# [36/820] ✓ arterial4x4_12/nt3: 20 个样本，累计 234 个
#  Retrying in 1 seconds
# Step #685.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 2ms, vehicles TOT 269 ACT 174 BUF 1
# [37/820] ✓ arterial4x4_18/nt12: 2 个样本，累计 236 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_20/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37055 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #737.00 (2ms ~= 500.00*RT, ~88000.00UPS, TraCI: 2ms, vehicles TOT 279 ACT 176 BUF 171
# [38/820] ✓ arterial4x4_6/nt1: 5 个样本，累计 241 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_26/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36867 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #649.00 (1ms ~= 1000.00*RT, ~174000.00UPS, TraCI: 1ms, vehicles TOT 258 ACT 174 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_11/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34455 (Attempt 1/3)
#  Retrying in 1 seconds
# [39/820] ✓ arterial4x4_15/nt2: 20 个样本，累计 261 个
# Step #744.00 (2ms ~= 500.00*RT, ~94500.00UPS, TraCI: 2ms, vehicles TOT 283 ACT 189 BUF 173
# [40/820] ✓ arterial4x4_7/nt14: 11 个样本，累计 272 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_33/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37351 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Step #648.00 (1ms ~= 1000.00*RT, ~172000.00UPS, TraCI: 2ms, vehicles TOT 256 ACT 172 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_8/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34967 (Attempt 1/3)
# [41/820] ✓ arterial4x4_43/nt2: 20 个样本，累计 292 个
#  Retrying in 1 seconds
# Step #687.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 272 ACT 181 BUF 1
# [42/820] ✓ arterial4x4_23/nt6: 2 个样本，累计 294 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_1/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35607 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 31886
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Step #660.00 (2ms ~= 500.00*RT, ~87500.00UPS, TraCI: 2ms, vehicles TOT 259 ACT 175 BUF 123
# Warmup progress: 100/300
# [43/820] ✓ arterial4x4_43/nt13: 0 个样本，累计 294 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_2/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30134 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #632.00 (1ms ~= 1000.00*RT, ~166000.00UPS, TraCI: 2ms, vehicles TOT 250 ACT 166 BUF 1
# [44/820] ✓ arterial4x4_37/nt2: 20 个样本，累计 314 个
# Warmup progress: 200/300
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/chengdu/chengdu.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32972 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Step #713.00 (1ms ~= 1000.00*RT, ~183000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 183 BUF 1
# Successfully connected to SUMO on port 39332
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# [45/820] ✓ arterial4x4_4/nt14: 13 个样本，累计 327 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33770 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 100/300
# Step #683.00 (1ms ~= 1000.00*RT, ~183000.00UPS, TraCI: 2ms, vehicles TOT 269 ACT 183 BUF 1
# [46/820] ✓ arterial4x4_43/nt14: 16 个样本，累计 343 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_24/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35930 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 33191
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Step #717.00 (2ms ~= 500.00*RT, ~89000.00UPS, TraCI: 2ms, vehicles TOT 275 ACT 178 BUF 157
# [47/820] ✓ arterial4x4_2/nt8: 3 个样本，累计 346 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_6/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33212 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Successfully connected to SUMO on port 34531
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 37055
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 36867
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 34455
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 37351
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 34967
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 35607
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 30134
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 33770
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 32972
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 35930
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Step #674.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 268 ACT 181 BUF 1
# Warmup progress: 100/300
# [48/820] ✓ arterial4x4_22/nt15: 4 个样本，累计 350 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_21/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36752 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 33212
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Step #648.00 (1ms ~= 1000.00*RT, ~168000.00UPS, TraCI: 2ms, vehicles TOT 249 ACT 168 BUF 1
# [49/820] ✓ arterial4x4_15/nt3: 20 个样本，累计 370 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_11/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36340 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #684.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 2ms, vehicles TOT 269 ACT 175 BUF 1
# [50/820] ✓ arterial4x4_4/nt5: 0 个样本，累计 370 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33441 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #717.00 (1ms ~= 1000.00*RT, ~188000.00UPS, TraCI: 2ms, vehicles TOT 276 ACT 188 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [51/820] ✓ arterial4x4_40/nt15: 4 个样本，累计 374 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_16/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38379 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #712.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 177 BUF 1
# [52/820] ✓ arterial4x4_11/nt16: 0 个样本，累计 374 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_20/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31807 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Step #691.00 (1ms ~= 1000.00*RT, ~173000.00UPS, TraCI: 2ms, vehicles TOT 270 ACT 173 BUF 1
# [53/820] ✓ arterial4x4_33/nt12: 1 个样本，累计 375 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_11/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35455 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #729.00 (1ms ~= 1000.00*RT, ~189000.00UPS, TraCI: 2ms, vehicles TOT 284 ACT 189 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_3/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38174 (Attempt 1/3)
# [54/820] ✓ arterial4x4_20/nt6: 4 个样本，累计 379 个
#  Retrying in 1 seconds
# Step #787.00 (2ms ~= 500.00*RT, ~89500.00UPS, TraCI: 2ms, vehicles TOT 288 ACT 179 BUF 206
# [55/820] ✓ arterial4x4_26/nt1: 1 个样本，累计 380 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_39/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 34132 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #729.00 (2ms ~= 500.00*RT, ~84000.00UPS, TraCI: 3ms, vehicles TOT 269 ACT 168 BUF 175
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_38/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38549 (Attempt 1/3)
# Step #706.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 3ms, vehicles TOT 274 ACT 181 BUF 1
# [56/820] ✓ arterial4x4_1/nt13: 3 个样本，累计 383 个
#  Retrying in 1 seconds
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_3/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38709 (Attempt 1/3)
# [57/820] ✓ arterial4x4_8/nt14: 15 个样本，累计 398 个
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 36752
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Step #698.00 (1ms ~= 1000.00*RT, ~180000.00UPS, TraCI: 2ms, vehicles TOT 272 ACT 180 BUF 1
# [58/820] ✓ arterial4x4_47/nt10: 1 个样本，累计 399 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_21/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30707 (Attempt 1/3)
# Warmup completed. Starting real-time simulation.
# Step #662.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 2ms, vehicles TOT 261 ACT 175 BUF 1
#  Retrying in 1 seconds
# [59/820] ✓ arterial4x4_24/nt9: 2 个样本，累计 401 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_44/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30801 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #773.00 (1ms ~= 1000.00*RT, ~184000.00UPS, TraCI: 2ms, vehicles TOT 286 ACT 184 BUF 1
# Step #682.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 1ms, vehicles TOT 267 ACT 181 BUF 1
# Successfully connected to SUMO on port 36340
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_8/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 35401 (Attempt 1/3)
# [60/820] ✓ arterial4x4_6/nt7: 2 个样本，累计 403 个
# [61/820] ✓ arterial4x4_2/nt14: 15 个样本，累计 418 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo Retrying in 1 seconds
#
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_18/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38509 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 33441
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Successfully connected to SUMO on port 38379
# ...
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 33526
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Step #722.00 (1ms ~= 1000.00*RT, ~172000.00UPS, TraCI: 3ms, vehicles TOT 269 ACT 172 BUF 1
# [789/820] ✓ arterial4x4_49/nt1: 2 个样本，累计 4234 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_47/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37931 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 36083
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 200/300
# Successfully connected to SUMO on port 36450
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Step #635.00 (1ms ~= 1000.00*RT, ~171000.00UPS, TraCI: 2ms, vehicles TOT 255 ACT 171 BUF 1
# [790/820] ✓ arterial4x4_16/nt3: 20 个样本，累计 4254 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_10/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31677 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 100/300
# Successfully connected to SUMO on port 32501
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Step #714.00 (1ms ~= 1000.00*RT, ~186000.00UPS, TraCI: 2ms, vehicles TOT 274 ACT 186 BUF 1
# [791/820] ✓ arterial4x4_12/nt10: 3 个样本，累计 4257 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_36/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31628 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 31432
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Step #762.00 (1ms ~= 1000.00*RT, ~159000.00UPS, TraCI: 4ms, vehicles TOT 269 ACT 159 BUF 2
# [792/820] ✓ arterial4x4_15/nt13: 3 个样本，累计 4260 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_20/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38314 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 38354
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 31399
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Successfully connected to SUMO on port 32190
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 34712
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 35270
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup completed. Starting real-time simulation.
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Step #656.00 (1ms ~= 1000.00*RT, ~178000.00UPS, TraCI: 2ms, vehicles TOT 261 ACT 178 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [793/820] ✓ arterial4x4_28/nt3: 20 个样本，累计 4280 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_4/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37205 (Attempt 1/3)
# Successfully connected to SUMO on port 38661
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 37931
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 31677
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Step #704.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 270 ACT 173 BUF 150)
# [794/820] ✓ arterial4x4_30/nt1: 3 个样本，累计 4283 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_24/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36550 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Step #705.00 (1ms ~= 1000.00*RT, ~178000.00UPS, TraCI: 2ms, vehicles TOT 273 ACT 178 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [795/820] ✓ arterial4x4_50/nt14: 11 个样本，累计 4294 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_18/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 31097 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 31628
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Successfully connected to SUMO on port 38314
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 200/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Step #640.00 (2ms ~= 500.00*RT, ~84500.00UPS, TraCI: 2ms, vehicles TOT 252 ACT 169 BUF 112
# [796/820] ✓ arterial4x4_17/nt13: 1 个样本，累计 4295 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_24/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 33285 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 37205
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Step #775.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 290 ACT 181 BUF 1
# [797/820] ✓ arterial4x4_27/nt8: 1 个样本，累计 4296 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_19/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 39610 (Attempt 1/3)
# Warmup progress: 100/300
#  Retrying in 1 seconds
# Step #669.00 (1ms ~= 1000.00*RT, ~169000.00UPS, TraCI: 2ms, vehicles TOT 261 ACT 169 BUF 1
# [798/820] ✓ arterial4x4_6/nt13: 1 个样本，累计 4297 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_45/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 32927 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Step #768.00 (2ms ~= 500.00*RT, ~93500.00UPS, TraCI: 2ms, vehicles TOT 289 ACT 187 BUF 187
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_33/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37964 (Attempt 1/3)
# [799/820] ✓ arterial4x4_37/nt10: 3 个样本，累计 4300 个
#  Retrying in 1 seconds
# Step #694.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 2ms, vehicles TOT 272 ACT 181 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# [800/820] ✓ arterial4x4_26/nt3: 20 个样本，累计 4320 个
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_38/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38373 (Attempt 1/3)
#  Retrying in 1 seconds
# Step #679.00 (1ms ~= 1000.00*RT, ~180000.00UPS, TraCI: 2ms, vehicles TOT 267 ACT 180 BUF 1
# [801/820] ✓ arterial4x4_7/nt11: 1 个样本，累计 4321 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_32/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 37718 (Attempt 1/3)
#  Retrying in 1 seconds
# Successfully connected to SUMO on port 36550
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 31097
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Step #668.00 (1ms ~= 1000.00*RT, ~170000.00UPS, TraCI: 2ms, vehicles TOT 260 ACT 170 BUF 1
# [802/820] ✓ arterial4x4_10/nt13: 0 个样本，累计 4321 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_15/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 38290 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup progress: 200/300
# Step #719.00 (1ms ~= 1000.00*RT, ~178000.00UPS, TraCI: 2ms, vehicles TOT 275 ACT 178 BUF 1
# [803/820] ✓ arterial4x4_7/nt16: 2 个样本，累计 4323 个
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_48/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 30719 (Attempt 1/3)
#  Retrying in 1 seconds
# Warmup completed. Starting real-time simulation.
# Step #699.00 (1ms ~= 1000.00*RT, ~177000.00UPS, TraCI: 1ms, vehicles TOT 275 ACT 177 BUF 1
# DEBUG: 使用的 SUMO 路径是: /usr/share/sumo/bin/sumo
# Starting SUMO with command: /usr/share/sumo/bin/sumo -c /root/autodl-tmp/SCU_TSC/sumo_simulation/environments/arterial4x4_6/arterial4x4.sumocfg --step-length 1.0 --no-warnings true --start --device.rerouting.probability 0 on port 36700 (Attempt 1/3)
# [804/820] ✓ arterial4x4_22/nt2: 20 个样本，累计 4343 个
#  Retrying in 1 seconds
# Step #677.00 (2ms ~= 500.00*RT, ~83500.00UPS, TraCI: 2ms, vehicles TOT 259 ACT 167 BUF 137
# [805/820] ✓ arterial4x4_20/nt1: 0 个样本，累计 4343 个
# Successfully connected to SUMO on port 33285
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 39610
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 32927
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Successfully connected to SUMO on port 37964
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 38373
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 37718
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup completed. Starting real-time simulation.
# Warmup progress: 0/300
# Warmup progress: 100/300
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Warmup completed. Starting real-time simulation.
# Step #717.00 (1ms ~= 1000.00*RT, ~183000.00UPS, TraCI: 4ms, vehicles TOT 276 ACT 183 BUF 1
# [806/820] ✓ arterial4x4_47/nt6: 2 个样本，累计 4345 个
# Successfully connected to SUMO on port 38290
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Successfully connected to SUMO on port 30719
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup progress: 100/300
# Step #727.00 (1ms ~= 1000.00*RT, ~187000.00UPS, TraCI: 2ms, vehicles TOT 269 ACT 187 BUF 1
# Step #719.00 (2ms ~= 500.00*RT, ~89000.00UPS, TraCI: 2ms, vehicles TOT 273 ACT 178 BUF 161
# [807/820] ✓ arterial4x4_4/nt3: 20 个样本，累计 4365 个
# [808/820] ✓ arterial4x4_36/nt3: 20 个样本，累计 4385 个
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup progress: 200/300
# Successfully connected to SUMO on port 36700
# Successfully connected to SUMO
# Starting warmup phase...
# Warmup progress: 0/300
# Warmup completed. Starting real-time simulation.
# Warmup progress: 100/300
# Warmup progress: 200/300
# Warmup completed. Starting real-time simulation.
# Step #707.00 (2ms ~= 500.00*RT, ~86500.00UPS, TraCI: 3ms, vehicles TOT 270 ACT 173 BUF 154
# Warmup completed. Starting real-time simulation.
# [809/820] ✓ arterial4x4_24/nt13: 1 个样本，累计 4386 个
# Step #664.00 (2ms ~= 500.00*RT, ~87500.00UPS, TraCI: 3ms, vehicles TOT 262 ACT 175 BUF 124
# Step #681.00 (1ms ~= 1000.00*RT, ~181000.00UPS, TraCI: 3ms, vehicles TOT 269 ACT 181 BUF 1
# [810/820] ✓ arterial4x4_45/nt8: 1 个样本，累计 4387 个
# Step #699.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 3ms, vehicles TOT 272 ACT 175 BUF 1
# [811/820] ✓ arterial4x4_19/nt11: 3 个样本，累计 4390 个
# [812/820] ✓ arterial4x4_24/nt12: 2 个样本，累计 4392 个
# Step #677.00 (1ms ~= 1000.00*RT, ~175000.00UPS, TraCI: 3ms, vehicles TOT 266 ACT 175 BUF 1
# [813/820] ✓ arterial4x4_18/nt3: 20 个样本，累计 4412 个
# Step #660.00 (2ms ~= 500.00*RT, ~88500.00UPS, TraCI: 4ms, vehicles TOT 259 ACT 177 BUF 123
# [814/820] ✓ arterial4x4_33/nt11: 4 个样本，累计 4416 个
# Step #704.00 (1ms ~= 1000.00*RT, ~180000.00UPS, TraCI: 2ms, vehicles TOT 272 ACT 180 BUF 1
# [815/820] ✓ arterial4x4_32/nt14: 12 个样本，累计 4428 个
# Step #762.00 (9ms ~= 111.11*RT, ~77333.33UPS, TraCI: 3ms, vehicles TOT 1600 ACT 696 BUF 8)
# [816/820] ✓ chengdu/2852225599: 20 个样本，累计 4448 个
# Step #634.00 (2ms ~= 500.00*RT, ~83000.00UPS, TraCI: 3ms, vehicles TOT 250 ACT 166 BUF 110
# [817/820] ✓ arterial4x4_48/nt16: 3 个样本，累计 4451 个
# Step #724.00 (2ms ~= 500.00*RT, ~89500.00UPS, TraCI: 3ms, vehicles TOT 276 ACT 179 BUF 162
# [818/820] ✓ arterial4x4_38/nt12: 2 个样本，累计 4453 个
# Step #686.00 (1ms ~= 1000.00*RT, ~176000.00UPS, TraCI: 5ms, vehicles TOT 270 ACT 176 BUF 1
# [819/820] ✓ arterial4x4_6/nt16: 3 个样本，累计 4456 个
# Step #686.00 (1ms ~= 1000.00*RT, ~178000.00UPS, TraCI: 2ms, vehicles TOT 272 ACT 178 BUF 1
# [820/820] ✓ arterial4x4_15/nt7: 4 个样本，累计 4460 个
#
# 生成 Dataset，总样本数: 4460
# Saving the dataset (1/1 shards): 100%|██████████| 4460/4460 [00:00<00:00, 118386.44 examples/s]
# ✓ Dataset 已保存到: grpo_dataset_two_scenarios
#
# === Dataset 统计 ===
# 总样本数: 4460
# 场景数: 51
# 信号灯数: 36

# %% [markdown]
# ## 1.8 Generate Synthetic SFT Dataset
#
# Based on the GRPO dataset, generate synthetic responses to create an SFT dataset.

# %%
import os
import json
import random
import re
from datasets import load_from_disk, Dataset

def extract_json_content(text, marker):
    pattern = f"【{marker}】(.*?)【/{marker}】"
    match = re.search(pattern, text, re.DOTALL)
    if match:
        return json.loads(match.group(1))
    return None

def generate_synthetic_response(messages):
    user_content = messages[-1]['content']
    
    # Check task type
    if "【signal_step_input_json】" in user_content:
        data = extract_json_content(user_content, "signal_step_input_json")
        if data:
            # Heuristic for signal_step
            scenario = data.get("scenario", {})
            phase_ids = scenario.get("phase_ids", [1, 3])
            
            # Simple heuristic: pick valid phase, valid time
            # Ideally pick a random one to prevent bias to one phase
            next_phase_id = random.choice(phase_ids)
            green_sec = random.randint(10, 60)
            
            return json.dumps({
                "next_phase_id": next_phase_id,
                "green_sec": green_sec
            })
            
    elif "【extend_decision_input_json】" in user_content:
        data = extract_json_content(user_content, "extend_decision_input_json")
        if data:
            # Heuristic for extend_decision
            # Simple heuristic: 50% yes/no
            should_extend = random.choice(["是", "否"])
            extend_sec = 0
            if should_extend == "是":
                extend_sec = random.randint(5, 30)
                
            return json.dumps({
                "extend": should_extend,
                "extend_sec": extend_sec
            })
            
    return None

def main():
    INPUT_PATH = "grpo_dataset_two_scenarios"
    OUTPUT_PATH = "sft_dataset_synthetic"
    
    if not os.path.exists(INPUT_PATH):
        print(f"Error: {INPUT_PATH} not found.")
        return

    print(f"Loading dataset from {INPUT_PATH}...")
    dataset = load_from_disk(INPUT_PATH)
    
    # Limit dataset to 3000 samples for SFT (doesn't need too much data)
    MAX_SFT_SAMPLES = 3000
    if len(dataset) > MAX_SFT_SAMPLES:
        print(f"Dataset has {len(dataset)} samples, limiting to {MAX_SFT_SAMPLES} for SFT...")
        indices = random.sample(range(len(dataset)), MAX_SFT_SAMPLES)
        dataset = dataset.select(indices)
    
    new_data = []
    
    print("Generating synthetic responses...")
    for item in dataset:
        prompt_messages = item['prompt'] # List of {role, content}
        
        response_json = generate_synthetic_response(prompt_messages)
        
        if response_json:
            # Create full conversation for SFT
            # Clone messages to avoid modifying original reference if any
            new_messages = [m.copy() for m in prompt_messages]
            new_messages.append({
                "role": "assistant",
                "content": response_json
            })
            
            new_data.append({
                "messages": new_messages
            })
    
    if not new_data:
        print("No valid samples generated!")
        return
        
    print(f"Generated {len(new_data)} samples.")
    
    # Create new dataset
    sft_dataset = Dataset.from_list(new_data)
    sft_dataset.save_to_disk(OUTPUT_PATH)
    print(f"Saved synthetic SFT dataset to {OUTPUT_PATH}")

    # Verify one sample
    print("\nSample 0:")
    print(json.dumps(sft_dataset[0]["messages"][-1], ensure_ascii=False, indent=2))

if __name__ == "__main__":
    main()
# Out:
# Loading dataset from grpo_dataset_two_scenarios...
# Dataset has 4460 samples, limiting to 3000 for SFT...
# Generating synthetic responses...
# Generated 3000 samples.
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 242431.30 examples/s]
# Saved synthetic SFT dataset to sft_dataset_synthetic
#
# Sample 0:
# {
#   "content": "{\"next_phase_id\": 6, \"green_sec\": 23}",
#   "role": "assistant"
# }

# %% [markdown]
# ## 1.9 SFT Training
#
# Train the model on the synthetic SFT dataset before GRPO.

# %%
import os
import torch
from unsloth import FastLanguageModel
from trl import SFTConfig, SFTTrainer
from datasets import load_from_disk
from unsloth.chat_templates import get_chat_template
from transformers import EarlyStoppingCallback

# ==================== Config ====================
max_seq_length = 1024
lora_rank = 32
# model_name = "rd211/Qwen3-0.6B-Instruct"
model_name = "Qwen/Qwen2.5-0.5B-Instruct"
output_dir = "checkpoints/sft_tsc_synthetic"
dataset_path = "sft_dataset_synthetic"

# ==================== Load Model ====================
print(f"Loading model: {model_name}")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    load_in_4bit=False,
    fast_inference=False,
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.7,
)

model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=lora_rank * 2,
    use_gradient_checkpointing="unsloth",
    random_state=3407,
)
model.config.use_cache = False

# ==================== Load Dataset ====================
if not os.path.isdir(dataset_path):
    raise FileNotFoundError(f"Dataset not found: {dataset_path}. Run generate_synthetic_sft_dataset.py first.")

dataset = load_from_disk(dataset_path)
print(f"Loaded {len(dataset)} samples for SFT.")

# Split dataset into train and test
dataset = dataset.train_test_split(test_size=0.05, seed=42)
train_dataset = dataset["train"]
eval_dataset = dataset["test"]

# Limit eval dataset to 200 samples for speed
if len(eval_dataset) > 500:
    eval_dataset = eval_dataset.select(range(500))

print(f"Train samples: {len(train_dataset)}")
print(f"Eval samples: {len(eval_dataset)}")

# ==================== Configure Trainer ====================
# Apply chat template
tokenizer = get_chat_template(
    tokenizer,
    chat_template="qwen-2.5", 
)

# Formatting function for chat 
def formatting_prompts_func(examples):
    convos = examples["messages"]
    
    # Logic to handle both batched and non-batched inputs
    if isinstance(convos, list) and len(convos) > 0 and isinstance(convos[0], dict):
        # Single conversation (list of dicts)
        texts = [tokenizer.apply_chat_template(convos, tokenize=False, add_generation_prompt=False)]
    else:
        # Batch of conversations (list of lists of dicts)
        texts = [tokenizer.apply_chat_template(convo, tokenize=False, add_generation_prompt=False) for convo in convos]
        
    return texts

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False, 
    formatting_func=formatting_prompts_func,
    args=SFTConfig(
        output_dir=output_dir,
        num_train_epochs=3, # Increase epochs relying on early stopping
        per_device_train_batch_size=4,
        per_device_eval_batch_size=1,
        gradient_accumulation_steps=4,
        learning_rate=2e-4, 
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        fp16_full_eval=not torch.cuda.is_bf16_supported(),
        bf16_full_eval=torch.cuda.is_bf16_supported(),
        logging_steps=10,
        eval_strategy="steps",
        eval_steps=30, # Evaluate every 30 steps
        save_strategy="steps",
        save_steps=30,
        load_best_model_at_end=True,
        metric_for_best_model="eval_loss",
        greater_is_better=False,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        report_to="none",
    ),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)] # Stop if no improvement for 3 eval steps (90 steps)
)


print("Starting SFT Training with Early Stopping...")
trainer.train()

print(f"Saving model to {output_dir}")
model.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
print("Done.")


# Clean up memory for the next stage
import gc
try:
    del model, tokenizer, trainer
except NameError:
    pass
gc.collect()
torch.cuda.empty_cache()
print("Memory cleaned up for GRPO stage.")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Loading model: Qwen/Qwen2.5-0.5B-Instruct
# Downloading Model from https://www.modelscope.cn to directory: model/models/unsloth/Qwen2.5-0.5B-Instruct
# 2026-01-23 16:00:20,408 - modelscope - INFO - Target directory already exists, skipping creation.
# ==((====))==  Unsloth 2026.1.4: Fast Qwen2 patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA GeForce RTX 4090 D. Num GPUs = 1. Max memory: 23.643 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2026.1.4 patched 24 layers with 24 QKV layers, 24 O layers and 24 MLP layers.
# Loaded 3000 samples for SFT.
# Train samples: 2850
# Eval samples: 150
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# Starting SFT Training with Early Stopping...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,850 | Num Epochs = 3 | Total steps = 537
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 4 x 1) = 16
#  "-____-"     Trainable parameters = 17,596,416 of 511,629,184 (3.44% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='481' max='537' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [481/537 10:05 < 01:10, 0.79 it/s, Epoch 2.68/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30</td>
#       <td>0.545500</td>
#       <td>0.160830</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.092100</td>
#       <td>0.090917</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.086900</td>
#       <td>0.085488</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.085000</td>
#       <td>0.081623</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.080800</td>
#       <td>0.079272</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.075900</td>
#       <td>0.078524</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.078200</td>
#       <td>0.076320</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.078400</td>
#       <td>0.074931</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.074300</td>
#       <td>0.073751</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.071300</td>
#       <td>0.072294</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.070400</td>
#       <td>0.071216</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.066500</td>
#       <td>0.070338</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.069900</td>
#       <td>0.069000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.068200</td>
#       <td>0.066668</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.064000</td>
#       <td>0.064861</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.061100</td>
#       <td>0.062956</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Not an error, but Qwen2ForCausalLM does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient

# %% [markdown]
# ## 2. 加载模型

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048
lora_rank = 32

os.environ["HF_HOME"] = "model"
os.environ["MODELSCOPE_CACHE"] = "model"

# BASE_MODEL_DIR = "model/models/qwen3-4B-SFT"
BASE_MODEL_DIR = "Qwen/Qwen2.5-0.5B-Instruct"
# BASE_MODEL_DIR = "rd211/Qwen3-0.6B-Instruct"
CHECKPOINT_DIR = "checkpoints/grpo_tsc_two_scenarios_latest"


def _looks_like_checkpoint(path: str) -> bool:
    if not os.path.isdir(path):
        return False
    marker_files = [
        "adapter_config.json",
        "adapter_model.safetensors",
        "adapter_model.bin",
        "config.json",
    ]
    return any(os.path.isfile(os.path.join(path, f)) for f in marker_files)


SFT_CHECKPOINT_DIR = "checkpoints/sft_tsc_synthetic"
GRPO_CHECKPOINT_DIR = "checkpoints/grpo_tsc_two_scenarios"

def _find_latest_checkpoint(checkpoint_dir: str) -> str | None:
    """Find the latest valid checkpoint in a directory."""
    if not os.path.isdir(checkpoint_dir):
        return None
    candidates = []
    for name in os.listdir(checkpoint_dir):
        path = os.path.join(checkpoint_dir, name)
        if _looks_like_checkpoint(path):
            # Extract step number if possible (e.g., checkpoint-100)
            try:
                step = int(name.split('-')[-1])
            except (ValueError, IndexError):
                step = 0
            candidates.append((step, path))
    if not candidates:
        return None
    # Return the checkpoint with the highest step number
    candidates.sort(key=lambda x: x[0], reverse=True)
    return candidates[0][1]

resume_from = CHECKPOINT_DIR if _looks_like_checkpoint(CHECKPOINT_DIR) else BASE_MODEL_DIR

# Priority: CHECKPOINT_DIR (latest symlink) > GRPO checkpoints > SFT checkpoint > base model
if _looks_like_checkpoint(CHECKPOINT_DIR):
    print(f"✓ 从 checkpoint 继续训练: {CHECKPOINT_DIR}")
    resume_from = CHECKPOINT_DIR
else:
    # Check for checkpoints in grpo_tsc_two_scenarios
    grpo_latest = _find_latest_checkpoint(GRPO_CHECKPOINT_DIR)
    if grpo_latest:
        print(f"✓ 从 GRPO checkpoint 继续训练: {grpo_latest}")
        resume_from = grpo_latest
    elif _looks_like_checkpoint(SFT_CHECKPOINT_DIR):
        print(f"✓ 从 SFT 模型开始训练: {SFT_CHECKPOINT_DIR}")
        resume_from = SFT_CHECKPOINT_DIR
    else:
        print(f"ℹ 从基础模型开始: {BASE_MODEL_DIR}")
        resume_from = BASE_MODEL_DIR


model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=resume_from,
    max_seq_length=max_seq_length,
    load_in_4bit=False,
    fast_inference=True,
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.8,
)

if resume_from == BASE_MODEL_DIR:
    model = FastLanguageModel.get_peft_model(
        model,
        r=lora_rank,
        target_modules=[
            "q_proj", "k_proj", "v_proj", "o_proj",
            "gate_proj", "up_proj", "down_proj",
        ],
        lora_alpha=lora_rank * 2,
        use_gradient_checkpointing="unsloth",
        random_state=3407,
    )
else:
    try:
        model.gradient_checkpointing_enable()
    except Exception:
        pass
    _trainable = [p for p in model.parameters() if p.requires_grad]
    if len(_trainable) == 0:
        for name, p in model.named_parameters():
            if "lora" in name.lower():
                p.requires_grad = True
        print("⚠️ checkpoint 未检测到可训练参数，已强制启用 LoRA 参数训练")

# Fix for GRPO generation: Must use left padding (applies to ALL cases)
tokenizer.padding_side = "left"
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

# Apply the same chat template as SFT training
from unsloth.chat_templates import get_chat_template
tokenizer = get_chat_template(
    tokenizer,
    chat_template="qwen-2.5",  # Must match SFT training template
)
print("✓ Applied qwen-2.5 chat template to match SFT training")

# Ensure BOS token is preserved - this is critical for generation
if tokenizer.bos_token_id is None:
    # For Qwen, <|im_start|> acts as BOS in chat context
    tokenizer.bos_token_id = tokenizer.convert_tokens_to_ids("<|im_start|>")
    print(f"设置 bos_token_id: {tokenizer.bos_token_id}")

print(f"Tokenizer padding_side: {tokenizer.padding_side}")
print(f"Tokenizer pad_token_id: {tokenizer.pad_token_id}")
print(f"Tokenizer bos_token_id: {tokenizer.bos_token_id}")

# %% [markdown]
# ## 3. 加载 Dataset

# %%
from datasets import load_from_disk
from datasets import Dataset

DATASET_PATH = "grpo_dataset_two_scenarios"
EVAL_TEST_SIZE = 0.001
EVAL_MAX_SAMPLES = 64
EVAL_SEED = 42

if not os.path.isdir(DATASET_PATH):
    raise FileNotFoundError(
        f"Dataset 不存在: {DATASET_PATH}\n"
        "请先运行 generate_grpo_dataset.py 生成离线 dataset"
    )

dataset = load_from_disk(DATASET_PATH)
print(f"✓ Dataset 加载成功: {DATASET_PATH}")
print(f"样本数: {len(dataset)}")

# Split out a small eval set to track real progress.
# Prefer stratified split by task_type so both tasks appear in eval.
try:
    if isinstance(dataset, Dataset) and ("task_type" in dataset.column_names):
        try:
            # Try stratified split first
            split = dataset.train_test_split(
                test_size=EVAL_TEST_SIZE,
                seed=EVAL_SEED,
                stratify_by_column="task_type",
            )
        except Exception as strat_err:
            # Fallback to non-stratified split if stratification fails
            print(f"⚠️ Stratified split failed ({strat_err}), using random split")
            split = dataset.train_test_split(test_size=EVAL_TEST_SIZE, seed=EVAL_SEED)
    else:
        split = dataset.train_test_split(test_size=EVAL_TEST_SIZE, seed=EVAL_SEED)

    train_dataset = split["train"]
    eval_dataset = split["test"]
    if len(eval_dataset) > EVAL_MAX_SAMPLES:
        eval_dataset = eval_dataset.select(range(EVAL_MAX_SAMPLES))

    print(f"✓ Train/Eval split: train={len(train_dataset)}, eval={len(eval_dataset)}")
    if "task_type" in train_dataset.column_names:
        from collections import Counter
        print("  - eval task_type counts:", Counter(eval_dataset["task_type"]))
except Exception as e:
    print(f"⚠️ Train/Eval split failed completely: {e}")
    train_dataset = dataset
    eval_dataset = None

# NOTE: Do NOT apply chat template here!
# GRPOTrainer expects prompt to be a list of messages, not a formatted string.
# It will apply the chat template internally using processing_class (tokenizer).
print("示例 Prompt (message list):")
print(dataset[0]["prompt"])

# %%
print(dataset[60]["prompt"])

# %% [markdown]
# ## 4. 导入 Reward Function

# %%
from tsc_reward_function import (
    tsc_reward_sim_fn,
    tsc_reward_format_fn,
    tsc_reward_constraint_fn,  # 新增
    cleanup_global_pool,
    reward_diag_snapshot,
    reward_diag_last,   
)
from transformers import TrainerCallback


class RewardDiagnosticsCallback(TrainerCallback):
    def __init__(self, kl_spike_threshold: float = 5.0):
        self.kl_spike_threshold = float(kl_spike_threshold)

    def on_log(self, args, state, control, logs=None, **kwargs):
        if not logs:
            return
        if not getattr(state, "is_world_process_zero", True):
            return

        # Periodic window summary (aligned to logging)
        if getattr(args, "logging_steps", None) and state.global_step % int(args.logging_steps) == 0:
            snap = reward_diag_snapshot(reset=True)
            total = snap.get("window_total", 0)
            invalid = snap.get("window_invalid", 0)
            rate = (invalid / total) if total else 0.0
            print(
                f"[reward_diag] steps {snap.get('window_start_step')}..{state.global_step} "
                f"invalid_rate={rate:.3f} ({invalid}/{total})"
            )
            by_task_total = snap.get("window_total_by_task", {}) or {}
            by_task_invalid = snap.get("window_invalid_by_task", {}) or {}
            by_reason = snap.get("window_reason_by_task", {}) or {}
            for task, t_total in sorted(by_task_total.items()):
                t_invalid = int(by_task_invalid.get(task, 0))
                t_rate = (t_invalid / t_total) if t_total else 0.0
                reasons = by_reason.get(task, {}) or {}
                reasons = {k: v for k, v in reasons.items() if k != "ok"}
                top = sorted(reasons.items(), key=lambda kv: kv[1], reverse=True)[:5]
                top_str = ", ".join([f"{k}:{v}" for k, v in top]) if top else "n/a"
                print(
                    f"[reward_diag]  - {task}: invalid_rate={t_rate:.3f} "
                    f"({t_invalid}/{t_total}) top={top_str}"
                )

        # KL spike dump
        kl = logs.get("kl", None)
        try:
            if kl is not None and float(kl) >= self.kl_spike_threshold:
                batch = reward_diag_last(state.global_step) or {}
                print(
                    f"[reward_diag] KL spike at step={state.global_step} kl={float(kl):.4f} batch={batch}"
                )
        except Exception:
            pass


diag_callback = RewardDiagnosticsCallback(kl_spike_threshold=5.0)

print("✓ Reward function 加载成功")

# %% [markdown]
# ## 5. 配置 GRPOTrainer

# %%
from trl import GRPOConfig, GRPOTrainer

# 快速验证模式：取消下面注释以使用短训练
# QUICK_VERIFY = True
QUICK_VERIFY = False  # 正式训练设为 False

# Eval 配置：eval_dataset 为空则自动禁用
DO_EVAL = False
EVAL_STEPS = 20
EVAL_BATCH_SIZE = 4  # 必须能整除 num_generations

config = GRPOConfig(
    output_dir="checkpoints/grpo_tsc_two_scenarios",

    # 批次配置
    per_device_train_batch_size=2,
    num_generations=4,  # Keep at 4 for proper GRPO
    gradient_accumulation_steps=4,

    # 生成配置
    max_completion_length=128,  
    temperature=0.8,
    top_p=0.9,
    top_k=40,
    use_vllm=False,

    # 训练配置
    learning_rate=2e-6,
    num_train_epochs=3,
    max_steps=-1,

    # GRPO 特定
    scale_rewards=True,

    # Eval (track real progress on held-out states)
    do_eval=DO_EVAL,
    eval_strategy="steps" if DO_EVAL else "no",
    eval_steps=EVAL_STEPS,
    eval_on_start=DO_EVAL,
    per_device_eval_batch_size=EVAL_BATCH_SIZE,

    # 日志与保存
    logging_steps=5,
    save_steps=100,
    # save_total_limit=1,

    # 优化器
    optim="adamw_torch",
    weight_decay=0.001,
    warmup_ratio=0.1,
    beta=0.01,             # KL 系数（0.0 默认不加载 ref）:contentReference[oaicite:1]{index=1}
    max_grad_norm=0.5,    # 梯度裁剪（防 KL spike）

    # 其他
    bf16=True,
    report_to="none",
    remove_unused_columns=False,
)

print(f"✓ GRPOConfig 配置完成 (模式: {'快速验证' if QUICK_VERIFY else '正式训练'})")
if QUICK_VERIFY:
    print(f"  - max_steps: {config.max_steps} (验证模式)")
else:
    print(f"  - max_steps: {config.max_steps} (全epoch)")

# %% [markdown]
# ## 6. 创建 GRPOTrainer 并开始训练

# %%
# Ensure output directory exists and is writable
import os
import stat

output_dir = config.output_dir
os.makedirs(output_dir, exist_ok=True)

# Verify we can write to the directory
test_file = os.path.join(output_dir, '.write_test')
try:
    with open(test_file, 'w') as f:
        f.write('test')
    os.remove(test_file)
    print(f"✓ Output directory {output_dir} is writable")
except PermissionError:
    print(f"⚠️ Cannot write to {output_dir}, attempting to fix permissions...")
    # Try to change permissions if we own the directory
    try:
        os.chmod(output_dir, stat.S_IRWXU | stat.S_IRWXG | stat.S_IROTH | stat.S_IXOTH)
        print(f"✓ Permissions fixed for {output_dir}")
    except Exception as e:
        raise PermissionError(
            f"Cannot write to checkpoint directory: {output_dir}\n"
            f"Please run: sudo chown -R $(whoami) {output_dir}"
        ) from e

trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    args=config,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    reward_funcs=[tsc_reward_sim_fn, tsc_reward_format_fn, tsc_reward_constraint_fn],
    callbacks=[diag_callback],
)



print("✓ GRPOTrainer 创建成功")
print(f"训练样本数: {len(train_dataset)}")
print(f"评估样本数: {0 if eval_dataset is None else len(eval_dataset)}")
print(f"每 epoch steps: {len(trainer.get_train_dataloader())}")

print("\n" + "="*60)
print("开始 GRPO 训练")
print("="*60 + "\n")

trainer.train()

print("\n" + "="*60)
print("训练完成")
print("="*60)

# %% [markdown]
# ## 7. 保存最终模型

# %%
final_output_dir = "checkpoints/grpo_tsc_two_scenarios_final"
trainer.save_model(final_output_dir)
tokenizer.save_pretrained(final_output_dir)
print(f"✓ 最终模型已保存到: {final_output_dir}")

# %% [markdown]
# ## 8. 清理资源

# %%
cleanup_global_pool()
print("✓ Simulator 池已清理")

# %% [markdown]
# ## 9. 测试推理（可选）

# %%
FastLanguageModel.for_inference(model)

test_sample = dataset[0]
test_prompt = test_sample["prompt"]

prompt_text = tokenizer.apply_chat_template(test_prompt, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)

print("测试生成:")
print("-" * 60)

outputs = model.generate(
    **inputs,
    max_new_tokens=256,
    temperature=0.7,
    top_p=0.9,
    do_sample=True,
)

generated_text = tokenizer.decode(outputs[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True)
print(generated_text)
print("-" * 60)
